# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ## Tienda 1

# %%
total1 = tienda['Precio'].sum()
print("Ingresos totales:", total1)
# Out:
# Ingresos totales: 1150880400.0

# %% [markdown]
# ## Tienda 2

# %%
total2 = tienda2['Precio'].sum()
print("Ingresos totales:",total2)
# Out:
# Ingresos totales: 1116343500.0

# %% [markdown]
# ## Tienda 3

# %%
total3 = tienda3['Precio'].sum()
print("Ingresos totales:",total3)
# Out:
# Ingresos totales: 1098019600.0

# %% [markdown]
# ## Tienda 4

# %%
total4 = tienda4['Precio'].sum()
print("Ingresos totales:",total4)
# Out:
# Ingresos totales: 1038375700.0

# %% [markdown]
# ## Gráfico

# %%
import matplotlib.pyplot as plt
import numpy as np

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [total1, total2, total3, total4]

plt.figure(figsize=(10, 6))
plt.bar(tiendas, ingresos, color=['orange', 'lime', 'blue', 'yellow'])
plt.title('Ingresos totales por tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingresos (MM)', color='black')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
ingresos_totales_todas_tiendas = total1 + total2 + total3 + total4
porcentaje_ingresos = [
    (total1 / ingresos_totales_todas_tiendas) * 100,
    (total2 / ingresos_totales_todas_tiendas) * 100,
    (total3 / ingresos_totales_todas_tiendas) * 100,
    (total4 / ingresos_totales_todas_tiendas) * 100
]

plt.figure(figsize=(8, 8))
plt.pie(porcentaje_ingresos, labels=tiendas, autopct='%1.1f%%', startangle=90, colors=['orange', 'lime', 'blue', 'yellow'])
plt.title('Ingresos Totales')
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ## Tienda 1

# %%
ventas1 = tienda['Categoría del Producto'].value_counts()
print("Ventas por categoría Tienda 1:")
display(ventas1)
# Out:
# Ventas por categoría Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %% [markdown]
# ## Tienda 2

# %%
ventas2 = tienda2['Categoría del Producto'].value_counts()
print("Ventas por categoría Tienda 2:")
display(ventas2)
# Out:
# Ventas por categoría Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %% [markdown]
# ## Tienda 3

# %%
ventas3 = tienda3['Categoría del Producto'].value_counts()
print("Ventas por categoría Tienda 3:")
display(ventas3)
# Out:
# Ventas por categoría Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %% [markdown]
# ## Tienda 4

# %%
ventas4 = tienda4['Categoría del Producto'].value_counts()
print("Ventas por categoría Tienda 4:")
display(ventas4)
# Out:
# Ventas por categoría Tienda 4:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %% [markdown]
# ## Gráfico

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

axes[0, 0].pie(ventas1, labels=ventas1.index, autopct='%1.1f%%', startangle=90)
axes[0, 0].set_title('Tienda 1')

axes[0, 1].pie(ventas2, labels=ventas2.index, autopct='%1.1f%%', startangle=90)
axes[0, 1].set_title('Tienda 2')

axes[1, 0].pie(ventas3, labels=ventas3.index, autopct='%1.1f%%', startangle=90)
axes[1, 0].set_title('Tienda 3')

axes[1, 1].pie(ventas4, labels=ventas4.index, autopct='%1.1f%%', startangle=90)
axes[1, 1].set_title('Tienda 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_promedio1 = tienda['Calificación'].mean()
print(f"Calificación promedio: {calificacion_promedio1:.2f}")
# Out:
# Calificación promedio: 3.98

# %% [markdown]
# ## Tienda 2

# %%
calificacion_promedio2 = tienda2['Calificación'].mean()
print(f"Calificación promedio: {calificacion_promedio2:.2f}")
# Out:
# Calificación promedio: 4.04

# %% [markdown]
# ## Tienda 3

# %%
calificacion_promedio3 = tienda3['Calificación'].mean()
print(f"Calificación promedio: {calificacion_promedio3:.2f}")
# Out:
# Calificación promedio: 4.05

# %% [markdown]
# ## Tienda 4

# %%
calificacion_promedio4 = tienda4['Calificación'].mean()
print(f"Calificación promedio: {calificacion_promedio4:.2f}")
# Out:
# Calificación promedio: 4.00

# %% [markdown]
# ## Gráfico

# %%
calificaciones = [calificacion_promedio1, calificacion_promedio2, calificacion_promedio3, calificacion_promedio4]

plt.figure(figsize=(10, 6))
plt.bar(tiendas, calificaciones, color=['orange', 'lime', 'blue', 'yellow'])
plt.title('Calificación Promedio por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
plt.ylim(0, 5)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ## Tienda 1

# %%
productos_mas_vendidos1 = tienda['Producto'].value_counts().head(5)
productos_menos_vendidos1 = tienda['Producto'].value_counts().tail(5)
print("Productos más vendidos:")
display(productos_mas_vendidos1)
print("\nProductos menos vendidos:")
display(productos_menos_vendidos1)
# Out:
# Productos más vendidos:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
# Productos menos vendidos:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %% [markdown]
# ## Tienda 2

# %%
productos_mas_vendidos2 = tienda2['Producto'].value_counts().head(5)
productos_menos_vendidos2 = tienda2['Producto'].value_counts().tail(5)
print("\nProductos más vendidos:")
display(productos_mas_vendidos2)
print("\nProductos menos vendidos:")
display(productos_menos_vendidos2)
# Out:
# Productos más vendidos:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
# Productos menos vendidos:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64

# %% [markdown]
# ## Tienda 3

# %%
productos_mas_vendidos3 = tienda3['Producto'].value_counts().head(5)
productos_menos_vendidos3 = tienda3['Producto'].value_counts().tail(5)
print("\nProductos más vendidos:")
display(productos_mas_vendidos3)
print("\nProductos menos vendidos:")
display(productos_menos_vendidos3)
# Out:
# Productos más vendidos:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: count, dtype: int64
# Productos menos vendidos:
# Producto
# Guitarra eléctrica         38
# Set de vasos               36
# Mochila                    36
# Microondas                 36
# Bloques de construcción    35
# Name: count, dtype: int64

# %% [markdown]
# ## Tienda 4

# %%
productos_mas_vendidos4 = tienda4['Producto'].value_counts().head(5)
productos_menos_vendidos4 = tienda4['Producto'].value_counts().tail(5)
print("\nProductos más vendidos:")
display(productos_mas_vendidos4)
print("\nProductos menos vendidos:")
display(productos_menos_vendidos4)
# Out:
# Productos más vendidos:
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Name: count, dtype: int64
# Productos menos vendidos:
# Producto
# Refrigerador                   38
# Ciencia de datos con Python    38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# ## Tienda 1

# %%
envio_promedio1 = tienda['Costo de envío'].mean()
print(f"Costo de envío promedio: {envio_promedio1:.2f}")
# Out:
# Costo de envío promedio: 26018.61

# %% [markdown]
# ## Tienda 2

# %%
envio_promedio2 = tienda2['Costo de envío'].mean()
print(f"Costo de envío promedio: {envio_promedio2:.2f}")
# Out:
# Costo de envío promedio: 25216.24

# %% [markdown]
# ## Tienda 3

# %%
envio_promedio3 = tienda3['Costo de envío'].mean()
print(f"Costo de envío promedio: {envio_promedio3:.2f}")
# Out:
# Costo de envío promedio: 24805.68

# %% [markdown]
# ## Tienda 4

# %%
envio_promedio4 = tienda4['Costo de envío'].mean()
print(f"Costo de envío promedio: {envio_promedio4:.2f}")
# Out:
# Costo de envío promedio: 23459.46

# %%
# Gráfico de dispersión para el costo de envío promedio por tienda
envios_promedio = [envio_promedio1, envio_promedio2, envio_promedio3, envio_promedio4]

plt.figure(figsize=(10, 6))
plt.scatter(tiendas, envios_promedio, color=['orange', 'lime', 'blue', 'yellow'], s=100)
plt.title('Costo de Envío Promedio por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Costo de Envío Promedio')
plt.grid(True)
plt.show()

# %% [markdown]
# # Informe Final

# %% [markdown]
# # Informe Final: Análisis Comparativo de Tiendas para Decisión de Venta
#
# ## Introducción
#
# El propósito de este informe es analizar y comparar el desempeño de cuatro tiendas diferentes con el fin de determinar cuál de ellas sería la mejor opción para vender, considerando diversos factores clave como ingresos, ventas por categoría y producto, calificaciones de clientes y costos de envío. El análisis se basa en los datos proporcionados y las visualizaciones generadas previamente.
#
# ## Análisis de Datos y Hallazgos
#
# ### 1. Ingresos Totales
#
# El análisis de ingresos totales por tienda reveló lo siguiente:
#
# *   **Tienda 1:** 1,150,880,400.00
# *   **Tienda 2:** 1,116,343,500.00
# *   **Tienda 3:** 1,098,019,600.00
# *   **Tienda 4:** 1,038,375,700.00
#
# La `Tienda 1` generó los mayores ingresos, mientras que la `Tienda 4` obtuvo los menores ingresos.
#
# La distribución porcentual de los ingresos totales fue el siguiente:
#
# *   **Tienda 1:** 26.1%
# *   **Tienda 2:** 25.4%
# *   **Tienda 3:** 24.9%
# *   **Tienda 4:** 23.6%
#
#
# ### 2. Ventas por Categoría
#
# La distribución de ventas por categoría varía entre las tiendas. Los gráficos de pastel muestran la proporción de cada categoría en las ventas totales de cada tienda.
#
# Se observa que la categoría `Muebles` es consistentemente una de las más vendidas en todas las tiendas, mientras que `Artículos para el hogar` tiende a tener una menor proporción de ventas.
#
# ### 3. Calificación Promedio de Clientes
#
# La satisfacción del cliente, medida por la calificación promedio, es un factor importante a considerar:
#
# *   **Tienda 1:** 3.98
# *   **Tienda 2:** 4.04
# *   **Tienda 3:** 4.05
# *   **Tienda 4:** 4.00
#
# La `Tienda 3` tiene la calificación promedio más alta, lo que sugiere una mayor satisfacción del cliente en comparación con la `Tienda 1`.
#
# ### 4. Productos Más y Menos Vendidos
#
# Identificar los productos más y menos vendidos en cada tienda ayuda a comprender la demanda y el rendimiento de los productos individuales.
#
# **Tienda 1:**
# *   Más vendidos: Microondas (60 unidades)
# *   Menos vendidos: Celular ABXY (33 unidades)
#
# **Tienda 2:**
# *   Más vendidos: Iniciando en programación	(65 unidades)
# *   Menos vendidos: Juego de mesa	(32 unidades)
#
# **Tienda 3:**
# *   Más vendidos: Kit de bancas	(57 unidades)
# *   Menos vendidos: Bloques de construcción	(35 unidades)
#
# **Tienda 4:**
# *   Más vendidos: Cama box	(62 unidades)
# *   Menos vendidos: Guitarra eléctrica (33 unidades)
#
# ### 5. Costo de Envío Promedio
#
# El costo de envío puede influir en la rentabilidad y la decisión de compra de los clientes:
#
# *   **Tienda 1:** 26,018.61
# *   **Tienda 2:** 25,216.24
# *   **Tienda 3:** 24,805.68
# *   **Tienda 4:** 23,459.46
#
# La `Tienda 1` tiene el costo de envío promedio más alto, mientras que la `Tienda 4` tiene el más bajo.
#
# ## Conclusión y Recomendación
#
# Considerando todos los factores analizados, la `Tienda 4` es la mejor opción para vender. Esta decisión se basa en que es la que tiene los ingresos más bajos y la segunda peor calificada por los clientes. A pesar de que tiene el menor costo de envío, el análisis integral de ingresos, ventas, satisfacción del cliente y costos de envío sugiere `Tienda 4` no generaría desequilibrio al momento de venderla.
#
# Es importante considerar que esta recomendación se basa en los datos disponibles y el análisis realizado. Se recomienda realizar un análisis más profundo de otros factores, como la rentabilidad neta, los costos operativos y las tendencias del mercado, antes de tomar una decisión final.

# %% [markdown]
# # Extra

# %%
import matplotlib.pyplot as plt

# Gráfico de dispersión para la Tienda 1
plt.figure(figsize=(10, 6))
plt.scatter(tienda['lon'], tienda['lat'], alpha=0.5, color='orange')
plt.title('Distribución Geográfica de Ventas - Tienda 1')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# Gráfico de dispersión para la Tienda 2
plt.figure(figsize=(10, 6))
plt.scatter(tienda2['lon'], tienda2['lat'], alpha=0.5, color='lime')
plt.title('Distribución Geográfica de Ventas - Tienda 2')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# Gráfico de dispersión para la Tienda 3
plt.figure(figsize=(10, 6))
plt.scatter(tienda3['lon'], tienda3['lat'], alpha=0.5, color='blue')
plt.title('Distribución Geográfica de Ventas - Tienda 3')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# Gráfico de dispersión para la Tienda 4
plt.figure(figsize=(10, 6))
plt.scatter(tienda4['lon'], tienda4['lat'], alpha=0.5, color='yellow')
plt.title('Distribución Geográfica de Ventas - Tienda 4')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()
